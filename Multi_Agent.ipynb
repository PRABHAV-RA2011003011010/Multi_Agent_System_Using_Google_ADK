# %%
from google.adk.agents import Agent
from google.adk.runners import InMemoryRunner
from google.adk.tools import google_search
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
root_agent = Agent(
    name="helpful_assistant",
    model="gemini-2.5-flash-lite",
    description="A simple agent that can answer general questions.",
    instruction="You are a helpful assistant. Use Google Search for current info or if unsure.",
    tools=[google_search],
)

print("✅ Root Agent defined.")
# Out:
# ✅ Root Agent defined.

# %%
# Create a runner to manage the agent
runner = InMemoryRunner()

# Run the agent with a test message
response = runner.run(
    agent=root_agent,
    message="What is artificial intelligence?",
)

# Print the response
print("Agent's response:")
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Create a runner to manage the agent
# ----> 2 runner = InMemoryRunner()
#       4 # Run the agent with a test message
#       5 response = runner.run(
#       6     agent=root_agent,
#       7     message="What is artificial intelligence?",
#       8 )
#
# File d:\Projects\Github_Repo\Multi_Agent_System_Using_Google_ADK\venv\Lib\site-packages\google\adk\runners.py:1356, in InMemoryRunner.__init__(self, agent, app_name, plugins, app)
#    1354 if app is None and app_name is None:
#    1355   app_name = 'InMemoryRunner'
# -> 1356 super().__init__(
#    1357     app_name=app_name,
#    1358     agent=agent,
#    1359     artifact_service=InMemoryArtifactService(),
#    1360     plugins=plugins,
#    1361     app=app,
#    1362     session_service=InMemorySessionService(),
#    1363     memory_service=InMemoryMemoryService(),
#    1364 )
#
# File d:\Projects\Github_Repo\Multi_Agent_System_Using_Google_ADK\venv\Lib\site-packages\google\adk\runners.py:149, in Runner.__init__(self, app, app_name, agent, plugins, artifact_service, session_service, memory_service, credential_service)
#     119 """Initializes the Runner.
#     120
#     121 Developers should provide either an `app` instance or both `app_name` and
#    (...)    140       if `app` is not provided but either `app_name` or `agent` is missing.
#     141 """
#     142 self.app = app
#     143 (
#     144     self.app_name,
#     145     self.agent,
#     146     self.context_cache_config,
#     147     self.resumability_config,
#     148     plugins,
# --> 149 ) = self._validate_runner_params(app, app_name, agent, plugins)
#     150 self.artifact_service = artifact_service
#     151 self.session_service = session_service
#
# File d:\Projects\Github_Repo\Multi_Agent_System_Using_Google_ADK\venv\Lib\site-packages\google\adk\runners.py:208, in Runner._validate_runner_params(self, app, app_name, agent, plugins)
#     206   resumability_config = app.resumability_config
#     207 elif not app_name or not agent:
# --> 208   raise ValueError(
#     209       'Either app or both app_name and agent must be provided.'
#     210   )
#     211 else:
#     212   context_cache_config = None
#
# ValueError: Either app or both app_name and agent must be provided.
