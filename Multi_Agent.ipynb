# %%
from google.adk.agents import Agent
from google.adk.runners import InMemoryRunner
from google.adk.tools import google_search
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from google.adk.agents import Agent
#       2 from google.adk.runners import InMemoryRunner
#       3 from google.adk.tools import google_search
#
# File d:\Projects\Github_Repo\Multi_Agent_System_Using_Google_ADK\venv\Lib\site-packages\google\adk\__init__.py:16
#       1 # Copyright 2025 Google LLC
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 from . import version
# ---> 16 from .agents.llm_agent import Agent
#      17 from .runners import Runner
#      19 __version__ = version.__version__
#
# File d:\Projects\Github_Repo\Multi_Agent_System_Using_Google_ADK\venv\Lib\site-packages\google\adk\agents\__init__.py:18
#      15 import logging
#      16 import sys
# ---> 18 from .base_agent import BaseAgent
#      19 from .invocation_context import InvocationContext
#      20 from .live_request_queue import LiveRequest
#
# File d:\Projects\Github_Repo\Multi_Agent_System_Using_Google_ADK\venv\Lib\site-packages\google\adk\agents\base_agent.py:40
#      37 from typing_extensions import override
#      38 from typing_extensions import TypeAlias
# ---> 40 from ..events.event import Event
#      41 from ..events.event_actions import EventActions
#      42 from ..telemetry import tracing
#
# File d:\Projects\Github_Repo\Multi_Agent_System_Using_Google_ADK\venv\Lib\site-packages\google\adk\events\__init__.py:15
#       1 # Copyright 2025 Google LLC
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
# ---> 15 from .event import Event
#      16 from .event_actions import EventActions
#      18 __all__ = [
#      19     'Event',
#      20     'EventActions',
#      21 ]
#
# File d:\Projects\Github_Repo\Multi_Agent_System_Using_Google_ADK\venv\Lib\site-packages\google\adk\events\event.py:26
#      23 from pydantic import ConfigDict
#      24 from pydantic import Field
# ---> 26 from ..models.llm_response import LlmResponse
#      27 from .event_actions import EventActions
#      30 class Event(LlmResponse):
#
# File d:\Projects\Github_Repo\Multi_Agent_System_Using_Google_ADK\venv\Lib\site-packages\google\adk\models\__init__.py:19
#      17 from .apigee_llm import ApigeeLlm
#      18 from .base_llm import BaseLlm
# ---> 19 from .gemma_llm import Gemma
#      20 from .google_llm import Gemini
#      21 from .llm_request import LlmRequest
#
# File d:\Projects\Github_Repo\Multi_Agent_System_Using_Google_ADK\venv\Lib\site-packages\google\adk\models\gemma_llm.py:25
#      22 from typing import AsyncGenerator
#      24 from google.adk.models.google_llm import Gemini
# ---> 25 from google.adk.models.llm_request import LlmRequest
#      26 from google.adk.models.llm_response import LlmResponse
#      27 from google.adk.utils.variant_utils import GoogleLLMVariant
#
# File d:\Projects\Github_Repo\Multi_Agent_System_Using_Google_ADK\venv\Lib\site-packages\google\adk\models\llm_request.py:27
#      24 from pydantic import Field
#      26 from ..agents.context_cache_config import ContextCacheConfig
# ---> 27 from ..tools.base_tool import BaseTool
#      28 from .cache_metadata import CacheMetadata
#      31 def _find_tool_with_function_declarations(
#      32     llm_request: LlmRequest,
#      33 ) -> Optional[types.Tool]:
#
# File d:\Projects\Github_Repo\Multi_Agent_System_Using_Google_ADK\venv\Lib\site-packages\google\adk\tools\__init__.py:69
#      64   logger.warning(
#      65       'MCP requires Python 3.10 or above. Please upgrade your Python'
#      66       ' version in order to use it.'
#      67   )
#      68 else:
# ---> 69   from .mcp_tool.mcp_toolset import MCPToolset
#      70   from .mcp_tool.mcp_toolset import McpToolset
#      72   __all__.extend([
#      73       'MCPToolset',
#      74       'McpToolset',
#      75   ])
#
# File d:\Projects\Github_Repo\Multi_Agent_System_Using_Google_ADK\venv\Lib\site-packages\google\adk\tools\mcp_tool\mcp_toolset.py:38
#      36 from ..tool_configs import BaseToolConfig
#      37 from ..tool_configs import ToolArgsConfig
# ---> 38 from .mcp_session_manager import MCPSessionManager
#      39 from .mcp_session_manager import retry_on_closed_resource
#      40 from .mcp_session_manager import SseConnectionParams
#
# File d:\Projects\Github_Repo\Multi_Agent_System_Using_Google_ADK\venv\Lib\site-packages\google\adk\tools\mcp_tool\mcp_session_manager.py:48
#      43     raise ImportError(
#      44         'MCP Tool requires Python 3.10 or above. Please upgrade your Python'
#      45         ' version.'
#      46     ) from e
#      47   else:
# ---> 48     raise e
#      50 logger = logging.getLogger('google_adk.' + __name__)
#      53 class StdioConnectionParams(BaseModel):
#
# File d:\Projects\Github_Repo\Multi_Agent_System_Using_Google_ADK\venv\Lib\site-packages\google\adk\tools\mcp_tool\mcp_session_manager.py:35
#      32 from pydantic import BaseModel
#      34 try:
# ---> 35   from mcp import ClientSession
#      36   from mcp import StdioServerParameters
#      37   from mcp.client.sse import sse_client
#
# File d:\Projects\Github_Repo\Multi_Agent_System_Using_Google_ADK\venv\Lib\site-packages\mcp\__init__.py:2
#       1 from .client.session import ClientSession
# ----> 2 from .client.session_group import ClientSessionGroup
#       3 from .client.stdio import StdioServerParameters, stdio_client
#       4 from .server.session import ServerSession
#
# File d:\Projects\Github_Repo\Multi_Agent_System_Using_Google_ADK\venv\Lib\site-packages\mcp\client\session_group.py:25
#      23 from mcp import types
#      24 from mcp.client.sse import sse_client
# ---> 25 from mcp.client.stdio import StdioServerParameters
#      26 from mcp.client.streamable_http import streamablehttp_client
#      27 from mcp.shared.exceptions import McpError
#
# File d:\Projects\Github_Repo\Multi_Agent_System_Using_Google_ADK\venv\Lib\site-packages\mcp\client\stdio\__init__.py:17
#      15 import mcp.types as types
#      16 from mcp.os.posix.utilities import terminate_posix_process_tree
# ---> 17 from mcp.os.win32.utilities import (
#      18     FallbackProcess,
#      19     create_windows_process,
#      20     get_windows_executable_command,
#      21     terminate_windows_process_tree,
#      22 )
#      23 from mcp.shared.message import SessionMessage
#      25 logger = logging.getLogger(__name__)
#
# File d:\Projects\Github_Repo\Multi_Agent_System_Using_Google_ADK\venv\Lib\site-packages\mcp\os\win32\utilities.py:22
#      20 # Windows-specific imports for Job Objects
#      21 if sys.platform == "win32":
# ---> 22     import pywintypes
#      23     import win32api
#      24     import win32con
#
# ModuleNotFoundError: No module named 'pywintypes'
